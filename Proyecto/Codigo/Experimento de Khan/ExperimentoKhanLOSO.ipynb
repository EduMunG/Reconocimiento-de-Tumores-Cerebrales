# %% [markdown]
# # Análisis del Dataset_Balanceado_700
# ## Experimento de Khan et al.

# %%
import os
import numpy as np

# Ruta del dataset
dataset_path = 'C:\\Users\\yleob\\OneDrive - Instituto Politecnico Nacional\\Documents\\1. Leo\\ESCOM\\Semestre 8\\TrabajoTerminal\\Reconocimiento-de-Tumores-Cerebrales\\Proyecto\\Codigo\\Dataset_Balanceado_700'

if not os.path.exists(dataset_path):
    # Ajuste de ruta si se corre desde Propuesta1/
    if os.path.exists('../Dataset_Balanceado_700'):
        dataset_path = '../Dataset_Balanceado_700'
    else:
        print(f"Error: La carpeta '{dataset_path}' no se encuentra en el directorio actual.")

if os.path.exists(dataset_path):
    # Obtener las carpetas de las clases
    classes = [d for d in os.listdir(dataset_path) if os.path.isdir(os.path.join(dataset_path, d))]
    
    print(f"{'Clase':<25} | {'Archivos':<10} | {'Total Imágenes':<15} | {'Dimensiones (WxH)':<20}")
    print("-" * 80)
    
    total_dataset_images = 0
    
    for class_name in classes:
        class_dir = os.path.join(dataset_path, class_name)
        files = [f for f in os.listdir(class_dir) if f.lower().endswith('.npz')]
        
        num_files = len(files)
        total_class_images = 0
        dims_set = set()
        
        for file_name in files:
            file_path = os.path.join(class_dir, file_name)
            try:
                with np.load(file_path) as data:
                    # Basado en la salida anterior, la clave es 'imagenes'
                    if 'imagenes' in data:
                        imgs = data['imagenes']
                        # Asumimos formato (N, H, W) donde N es el numero de imagenes
                        n_imgs = imgs.shape[0]
                        total_class_images += n_imgs
                        
                        if len(imgs.shape) >= 3:
                             dims_set.add(f"{imgs.shape[2]}x{imgs.shape[1]}") # WxH
                    else:
                        # Si no encuentra 'imagenes', intentar listar claves disponibles
                        print(f"Advertencia: 'imagenes' no encontrado en {file_name}. Claves: {list(data.files)}")

            except Exception as e:
                print(f"Error leyendo {file_name}: {e}")

        total_dataset_images += total_class_images
        
        dims_summary = ", ".join(list(dims_set)) if dims_set else "N/A"
        
        print(f"{class_name:<25} | {num_files:<10} | {total_class_images:<15} | {dims_summary:<20}")

    print("-" * 80)
    print(f"Total de imágenes en el dataset: {total_dataset_images}")
# Out:
# Clase                     | Archivos   | Total Imágenes  | Dimensiones (WxH)
# --------------------------------------------------------------------------------
# Adenoma_hipofisario       | 62         | 699             | 128x128
# Glioma                    | 89         | 699             | 128x128
# Meningioma                | 82         | 700             | 128x128
# --------------------------------------------------------------------------------
# Total de imágenes en el dataset: 2098

# %% [markdown]
# # Implementación de CNN Cuántica con Validación Leave One Subject Out
#
# Implementación del flujo de Khan:
# 0. **Preprocesamiento Clásico**: Se realiza una normalización de 0 a 1
# 1. **Preprocesamiento Cuántico**: Se aplica convolución cuántica a las imágenes.
# 2. **División de Datos**: Se respeta la estructura de pacientes (archivos .npz) para evitar data leakage. Se separa un 15% para Test y el resto para LOSO.
# 3. **Entrenamiento**: Se entrena una Red Neuronal (MLP) sobre las características cuánticas.
# 4. **Evaluación**: Se reportan métricas de rendimiento.

# %%
import sys
# Aseguramos que se pueda importar quantum_utils si está en el mismo directorio
sys.path.append('.')

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import StratifiedGroupKFold, train_test_split
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm
import quantum_utils as qu

# Configuración de dispositivo
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Usando dispositivo de entrenamiento (Red Neuronal): {device}")
# Out:
# Usando dispositivo de entrenamiento (Red Neuronal): cuda

# %%
class RedNeuronalGeneral(nn.Module):
    def __init__(self, input_shape, num_classes=3):
        super(RedNeuronalGeneral, self).__init__()
        
        # 1. Calculamos dinámicamente el tamaño aplanado (Flatten)
        self.input_dim = np.prod(input_shape)
        
        # print(f"Inicializando red para entrada {input_shape} -> {self.input_dim} neuronas de entrada.")

        # 2. Definimos la arquitectura Flatten + MLP
        #       Flatten -> Dense -> Dense -> Out
        
        self.flatten = nn.Flatten()
        
        self.layers = nn.Sequential(
            # Bloque Denso 1 
            nn.Linear(self.input_dim, 256), # De n entradas a 256 neuronas
            nn.BatchNorm1d(256), # Batch Normalization
            nn.LeakyReLU(0.1), # Activación LeakyReLU alpha=0.1
            nn.Dropout(0.3), # Dropout 30%
            
            # Bloque Denso 2
            nn.Linear(256, 128), # De 256 a 128 neuronas
            nn.BatchNorm1d(128), # Batch Normalization
            nn.LeakyReLU(0.1), # Activación LeakyReLU alpha=0.1
            nn.Dropout(0.2), # Dropout 20%
            
            # Capa de Salida (3 clases: Meningioma, Glioma, T. Pituitario)
            nn.Linear(128, num_classes)
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.layers(x)
        return logits

# %%
def cargar_y_procesar_dataset(dataset_path, save_dir=None, num_qubits=4, embedding='amplitude', feature_maps=1, max_images_per_class=None):
    """
    Carga los archivos .npz, aplica convolución cuántica y estructura los datos para CV.
    Si save_dir es proporcionado, guarda y carga los mapas de características procesados.
    """
    print(f"Usando convolución cuántica con {num_qubits} qubits, embedding '{embedding}', feature maps: {feature_maps}")
    
    # Crear directorio principal de guardado si no existe
    if save_dir and not os.path.exists(save_dir):
        os.makedirs(save_dir)

    features_list = []
    labels_list = []
    groups_list = []
    
    class_map = {}
    classes = sorted([d for d in os.listdir(dataset_path) if os.path.isdir(os.path.join(dataset_path, d))])
    for idx, c in enumerate(classes):
        class_map[c] = idx
    
    print(f"Mapeo de Clases: {class_map}")
    
    for class_name in classes:
        class_dir = os.path.join(dataset_path, class_name)
        files = [f for f in os.listdir(class_dir) if f.lower().endswith('.npz')]
        
        if max_images_per_class:
            files = files[:max_images_per_class]
            
        # Crear subdirectorio de clase en el caché
        class_save_dir = None
        if save_dir:
            class_save_dir = os.path.join(save_dir, class_name)
            os.makedirs(class_save_dir, exist_ok=True)
        
        print(f"Procesando clase {class_name} ({len(files)} pacientes)...")
        
        for file_name in tqdm(files, desc=f"Clase {class_name}"):
            file_path = os.path.join(class_dir, file_name)
            patient_id = file_name.replace('.npz', '')
            
            # --- 1. VERIFICAR CACHÉ ---
            save_file_path = os.path.join(class_save_dir, f"{patient_id}_qfeat.npz") if save_dir else None
            
            if save_file_path and os.path.exists(save_file_path):
                try:
                    with np.load(save_file_path) as data:
                        q_feats_patient = data['features'] # Shape (N, C, H, W)
                        
                    for q_feat in q_feats_patient:
                        features_list.append(torch.tensor(q_feat, dtype=torch.float32))
                        labels_list.append(class_map[class_name])
                        groups_list.append(patient_id)
                    continue # El paciente ya estaba procesado, saltamos al siguiente
                except Exception as e:
                    print(f"Advertencia: Archivo caché corrupto para {patient_id}. Recalculando... Error: {e}")

            # --- 2. CALCULAR CONVOLUCIÓN CUÁNTICA ---
            try:
                patient_q_feats = [] # Lista temporal para guardar las imágenes de este paciente
                
                with np.load(file_path) as data:
                    if 'imagenes' in data:
                        imgs = data['imagenes'] 
                        
                        for i in range(imgs.shape[0]):
                            img = imgs[i]
                            
                            img_min = np.min(img)
                            img_max = np.max(img)

                            if img_max - img_min > 1e-6:
                                img = (img - img_min) / (img_max - img_min)
                            else:
                                img = np.zeros_like(img, dtype=np.float32)

                            # quantum_conv devuelve (H_out, W_out, channels)
                            q_feat = qu.quantum_conv(img, num_qubits, embedding, feature_maps)
                            
                            # Transponer a formato PyTorch (C, H, W) usando numpy antes de guardar
                            q_feat_transposed = np.transpose(q_feat, (2, 0, 1))
                            patient_q_feats.append(q_feat_transposed)
                            
                            # Añadir a las listas de entrenamiento
                            features_list.append(torch.tensor(q_feat_transposed, dtype=torch.float32))
                            labels_list.append(class_map[class_name])
                            groups_list.append(patient_id)
                            
                # --- 3. GUARDAR EN CACHÉ ---
                if save_file_path and patient_q_feats:
                    # Guardamos el arreglo comprimido para ahorrar espacio en disco
                    np.savez_compressed(save_file_path, features=np.array(patient_q_feats))
                        
            except Exception as e:
                print(f"Error al procesar {file_name}: {e}")
                raise e
                
    return features_list, labels_list, groups_list

# Parámetros Cuánticos
NUM_QUBITS = 4
EMBEDDING = 'angle' 
FEATURE_MAPS = 1
DIRECTORIO_CACHE = './Dataset_Cuantico_Procesado' # Define aquí tu ruta de guardado

print("Iniciando extracción de características cuánticas...")
X_raw, y_raw, group_raw = cargar_y_procesar_dataset(
    dataset_path=dataset_path, 
    save_dir=DIRECTORIO_CACHE,
    num_qubits=NUM_QUBITS, 
    embedding=EMBEDDING, 
    feature_maps=FEATURE_MAPS
)

X_all = torch.stack(X_raw)
y_all = torch.tensor(y_raw, dtype=torch.long)
groups_all = np.array(group_raw)
# Out:
# Iniciando extracción de características cuánticas...
# Usando convolución cuántica con 4 qubits, embedding 'angle', feature maps: 1
# Mapeo de Clases: {'Adenoma_hipofisario': 0, 'Glioma': 1, 'Meningioma': 2}
# Procesando clase Adenoma_hipofisario (62 pacientes)...
# Clase Adenoma_hipofisario:   0%|          | 0/62 [00:00<?, ?it/s]
# Procesando clase Glioma (89 pacientes)...
# Clase Glioma:   0%|          | 0/89 [00:00<?, ?it/s]
# Procesando clase Meningioma (82 pacientes)...
# Clase Meningioma:   0%|          | 0/82 [00:00<?, ?it/s]

# %%
# --- ESTRATEGIA DE DIVISIÓN DE DATOS ---
# 1. Separar Test Set (15% de PACIENTES) preservando estratificación
#    Primero identificamos etiquetas por paciente para estratificar
unique_patients, patient_indices = np.unique(groups_all, return_index=True)
patient_labels = y_all[patient_indices].numpy()

train_val_patients, test_patients = train_test_split(unique_patients, 
                                                    test_size=0.15, 
                                                    stratify=patient_labels,
                                                    random_state=42)

print(f"Total Pacientes: {len(unique_patients)}")
print(f"Pacientes Train/Val: {len(train_val_patients)}")
print(f"Pacientes Test: {len(test_patients)}")

# Crear máscaras booleanas para filtrar X_all y y_all
# np.isin verifica si cada elemento de groups_all está en la lista de pacientes
mask_train_val = np.isin(groups_all, train_val_patients)
mask_test = np.isin(groups_all, test_patients)

X_train_val = X_all[mask_train_val]
y_train_val = y_all[mask_train_val]
groups_train_val = groups_all[mask_train_val]

X_test = X_all[mask_test]
y_test = y_all[mask_test]

print(f"Imágenes Train/Val: {len(X_train_val)}")
print(f"Imágenes Test: {len(X_test)}")
# Out:
# Total Pacientes: 233
# Pacientes Train/Val: 198
# Pacientes Test: 35
# Imágenes Train/Val: 1770
# Imágenes Test: 328

# %%
# --- LEAVE-ONE-SUBJECT-OUT (LOSO) CROSS VALIDATION ---
from sklearn.model_selection import LeaveOneGroupOut

BATCH_SIZE = 32
EPOCHS = 50

# Instanciamos LeaveOneGroupOut
logo = LeaveOneGroupOut()

fold_metrics = []
history_per_fold = []

# Obtenemos el número total de particiones (que será igual al número de pacientes en train_val)
n_splits = logo.get_n_splits(X_train_val, y_train_val, groups_train_val)

print(f"Iniciando Leave-One-Subject-Out Cross Validation ({n_splits} pacientes/folds)...")

# Iteramos usando logo.split
for fold, (train_idx, val_idx) in enumerate(logo.split(X_train_val, y_train_val, groups_train_val)):
    print(f"\nFold {fold+1}/{n_splits}")
    
    # Crear datasets para el fold actual
    X_f_train, y_f_train = X_train_val[train_idx], y_train_val[train_idx]
    X_f_val, y_f_val = X_train_val[val_idx], y_train_val[val_idx]
    
    train_ds = TensorDataset(X_f_train, y_f_train)
    val_ds = TensorDataset(X_f_val, y_f_val)
    
    train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, drop_last=True)
    val_loader = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False)
    
    # Inicializar Modelo
    input_shape = X_all.shape[1:]
    model = RedNeuronalGeneral(input_shape=input_shape, num_classes=3).to(device)
    
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.CrossEntropyLoss()
    
    # Historial para graficar
    fold_history = {'train_loss': [], 'val_loss': [], 'val_acc': []}
    
    for epoch in range(EPOCHS):
        # Train
        model.train()
        running_loss = 0.0
        
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item()
            
        avg_train_loss = running_loss / len(train_loader)
        
        # Validation
        model.eval()
        val_loss = 0.0
        correct_val = 0
        total_val = 0
        
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                
                _, predicted = torch.max(outputs.data, 1)
                total_val += labels.size(0)
                correct_val += (predicted == labels).sum().item()
        
        avg_val_loss = val_loss / len(val_loader)
        val_accuracy = 100 * correct_val / total_val
        
        fold_history['train_loss'].append(avg_train_loss)
        fold_history['val_loss'].append(avg_val_loss)
        fold_history['val_acc'].append(val_accuracy)
        
        if (epoch % 10 == 0) or (epoch == EPOCHS - 1):
            print(f"  Epoch {epoch+1}: Train Loss: {avg_train_loss:.4f} | Val Acc: {val_accuracy:.2f}%")
    
    print(f"  Final Val Acc Fold {fold+1}: {fold_history['val_acc'][-1]:.2f}%")
    history_per_fold.append(fold_history)
    fold_metrics.append(fold_history['val_acc'][-1])

print("\n--- Resultados Leave-One-Subject-Out (LOSO) ---")
print(f"Accuracy promedio a través de los pacientes: {np.mean(fold_metrics):.2f}% +/- {np.std(fold_metrics):.2f}%")
# Out:
# Iniciando Leave-One-Subject-Out Cross Validation (198 pacientes/folds)...
#
# Fold 1/198
#   Epoch 1: Train Loss: 0.5870 | Val Acc: 100.00%
#   Epoch 11: Train Loss: 0.0766 | Val Acc: 100.00%
#   Epoch 21: Train Loss: 0.
| Val Acc: 50.00%
#   Epoch 11: Train Loss: 0.0680 | Val Acc: 25.00%
#   Epoch 21: Train Loss: 0.0274 | Val Acc: 75.00%
#   Epoch 31: Train Loss: 0.0460 | Val Acc: 25.00%
#   Epoch 41: Train Loss: 0.0157 | Val Acc: 16.67%
#   Epoch 50: Train Loss: 0.0315 | Val Acc: 75.00%
#   Final Val Acc Fold 79: 75.00%
#
# Fold 80/198
#   Epoch 1: Train Loss: 0.6316 | Val Acc: 100.00%
#   Epoch 11: Train Loss: 0.0468 | Val Acc: 81.82%
#   Epoch 21: Train Loss: 0.0830 | Val Acc: 72.73%
#   Epoch 31: Train Loss: 0.0200 | Val Acc: 36.36%
#   Epoch 41: Train Loss: 0.0179 | Val Acc: 81.82%
#   Epoch 50: Train Loss: 0.0129 | Val Acc: 100.00%
#   Final Val Acc Fold 80: 100.00%
#
# Fold 81/198
#   Epoch 1: Train Loss: 0.5859 | Val Acc: 100.00%
#   Epoch 11: Train Loss: 0.0589 | Val Acc: 0.00%
#   Epoch 21: Train Loss: 0.0375 | Val Acc: 0.00%
#   Epoch 31: Train Loss: 0.0142 | Val Acc: 0.00%
#   Epoch 41: Train Loss: 0.0278 | Val Acc: 0.00%
#   Epoch 50: Train Loss: 0.0313 | Val Acc: 0.00%
#   Final Val Acc Fold 81: 0.00%
#
# Fold 82/198
#   Epoch 1: Train Loss: 0.6024 | Val Acc: 100.00%
#   Epoch 11: Train Loss: 0.0536 | Val Acc: 100.00%
#   Epoch 21: Train Loss: 0.0241 | Val Acc: 100.00%
#   Epoch 31: Train Loss: 0.0173 | Val Acc: 100.00%
#   Epoch 41: Train Loss: 0.0146 | Val Acc: 100.00%
#   Epoch 50: Train Loss: 0.0293 | Val Acc: 100.00%
#   Final Val Acc Fold 82: 100.00%
#
# Fold 83/198
#   Epoch 1: Train Loss: 0.5947 | Val Acc: 100.00%
#   Epoch 11: Train Loss: 0.0687 | Val Acc: 100.00%
#   Epoch 21: Train Loss: 0.0343 | Val Acc: 60.00%
#   Epoch 31: Train Loss: 0.0237 | Val Acc: 90.00%
#   Epoch 41: Train Loss: 0.0250 | Val Acc: 100.00%
#   Epoch 50: Train Loss: 0.0123 | Val Acc: 80.00%
#   Final Val Acc Fold 83: 80.00%
#
# Fold 84/198
#   Epoch 1: Train Loss: 0.5888 | Val Acc: 25.00%
#   Epoch 11: Train Loss: 0.0726 | Val Acc: 66.67%
#   Epoch 21: Train Loss: 0.0346 | Val Acc: 41.67%
#   Epoch 31: Train Loss: 0.0432 | Val Acc: 66.67%
#   Epoch 41: Train Loss: 0.0260 | Val Acc: 41.67%
#   Epoch 50: Train Loss: 0.0102 | Val Acc: 58.33%
#   Final Val Acc Fold 84: 58.33%
#
# Fold 85/198
#   Epoch 1: Train Loss: 0.5859 | Val Acc: 0.00%
#   Epoch 11: Train Loss: 0.0532 | Val Acc: 0.00%
#   Epoch 21: Train Loss: 0.0446 | Val Acc: 100.00%
#   Epoch 31: Train Loss: 0.0409 | Val Acc: 100.00%
#   Epoch 41: Train Loss: 0.0124 | Val Acc: 0.00%
#   Epoch 50: Train Loss: 0.0115 | Val Acc: 0.00%
#   Final Val Acc Fold 85: 0.00%
#
# Fold 86/198
#   Epoch 1: Train Loss: 0.5794 | Val Acc: 100.00%
#   Epoch 11: Train Loss: 0.0466 | Val Acc: 30.00%
#   Epoch 21: Train Loss: 0.0451 | Val Acc: 40.00%
#   Epoch 31: Train Loss: 0.0180 | Val Acc: 30.00%
#   Epoch 41: Train Loss: 0.0128 | Val Acc: 70.00%
#   Epoch 50: Train Loss: 0.0429 | Val Acc: 30.00%
#   Final Val Acc Fold 86: 30.00%
#
# Fold 87/198
#   Epoch 1: Train Loss: 0.5839 | Val Acc: 0.00%
#   Epoch 11: Train Loss: 0.0740 | Val Acc: 0.00%
#   Epoch 21: Train Loss: 0.0310 | Val Acc: 0.00%
#   Epoch 31: Train Loss: 0.0315 | Val Acc: 0.00%
#   Epoch 41: Train Loss: 0.0039 | Val Acc: 0.00%
#   Epoch 50: Train Loss: 0.0116 | Val Acc: 0.00%
#   Final Val Acc Fold 87: 0.00%
#
# Fold 88/198
#   Epoch 1: Train Loss: 0.5995 | Val Acc: 8.33%
#   Epoch 11: Train Loss: 0.0769 | Val Acc: 25.00%
#   Epoch 21: Train Loss: 0.0265 | Val Acc: 83.33%
#   Epoch 31: Train Loss: 0.0339 | Val Acc: 100.00%
#   Epoch 41: Train Loss: 0.0189 | Val Acc: 50.00%
#   Epoch 50: Train Loss: 0.0200 | Val Acc: 100.00%
#   Final Val Acc Fold 88: 100.00%
#
# Fold 89/198
#   Epoch 1: Train Loss: 0.5932 | Val Acc: 100.00%
#   Epoch 11: Train Loss: 0.
| Val Acc: 50.00%
#   Epoch 11: Train Loss: 0.0554 | Val Acc: 0.00%
#   Epoch 21: Train Loss: 0.0385 | Val Acc: 100.00%
#   Epoch 31: Train Loss: 0.0441 | Val Acc: 100.00%
#   Epoch 41: Train Loss: 0.0288 | Val Acc: 100.00%
#   Epoch 50: Train Loss: 0.0047 | Val Acc: 100.00%
#   Final Val Acc Fold 112: 100.00%
#
# Fold 113/198
#   Epoch 1: Train Loss: 0.6223 | Val Acc: 0.00%
#   Epoch 11: Train Loss: 0.0602 | Val Acc: 66.67%
#   Epoch 21: Train Loss: 0.0308 | Val Acc: 66.67%
#   Epoch 31: Train Loss: 0.0258 | Val Acc: 66.67%
#   Epoch 41: Train Loss: 0.0162 | Val Acc: 66.67%
#   Epoch 50: Train Loss: 0.0221 | Val Acc: 33.33%
#   Final Val Acc Fold 113: 33.33%
#
# Fold 114/198
#   Epoch 1: Train Loss: 0.5852 | Val Acc: 0.00%
#   Epoch 11: Train Loss: 0.0684 | Val Acc: 100.00%
#   Epoch 21: Train Loss: 0.0301 | Val Acc: 25.00%
#   Epoch 31: Train Loss: 0.0546 | Val Acc: 25.00%
#   Epoch 41: Train Loss: 0.0120 | Val Acc: 0.00%
#   Epoch 50: Train Loss: 0.0289 | Val Acc: 0.00%
#   Final Val Acc Fold 114: 0.00%
#
# Fold 115/198
#   Epoch 1: Train Loss: 0.5884 | Val Acc: 0.00%
#   Epoch 11: Train Loss: 0.0835 | Val Acc: 40.00%
#   Epoch 21: Train Loss: 0.0222 | Val Acc: 20.00%
#   Epoch 31: Train Loss: 0.0281 | Val Acc: 0.00%
#   Epoch 41: Train Loss: 0.0354 | Val Acc: 60.00%
#   Epoch 50: Train Loss: 0.0204 | Val Acc: 20.00%
#   Final Val Acc Fold 115: 20.00%
#
# Fold 116/198
#   Epoch 1: Train Loss: 0.5799 | Val Acc: 0.00%
#   Epoch 11: Train Loss: 0.0458 | Val Acc: 0.00%
#   Epoch 21: Train Loss: 0.0321 | Val Acc: 0.00%
#   Epoch 31: Train Loss: 0.0263 | Val Acc: 0.00%
#   Epoch 41: Train Loss: 0.0234 | Val Acc: 0.00%
#   Epoch 50: Train Loss: 0.0222 | Val Acc: 0.00%
#   Final Val Acc Fold 116: 0.00%
#
# Fold 117/198
#   Epoch 1: Train Loss: 0.5675 | Val Acc: 0.00%
#   Epoch 11: Train Loss: 0.0655 | Val Acc: 0.00%
#   Epoch 21: Train Loss: 0.0273 | Val Acc: 0.00%
#   Epoch 31: Train Loss: 0.0254 | Val Acc: 0.00%
#   Epoch 41: Train Loss: 0.0100 | Val Acc: 0.00%
#   Epoch 50: Train Loss: 0.0242 | Val Acc: 0.00%
#   Final Val Acc Fold 117: 0.00%
#
# Fold 118/198
#   Epoch 1: Train Loss: 0.5759 | Val Acc: 0.00%
#   Epoch 11: Train Loss: 0.0537 | Val Acc: 80.00%
#   Epoch 21: Train Loss: 0.0208 | Val Acc: 100.00%
#   Epoch 31: Train Loss: 0.0260 | Val Acc: 100.00%
#   Epoch 41: Train Loss: 0.0177 | Val Acc: 100.00%
#   Epoch 50: Train Loss: 0.0081 | Val Acc: 100.00%
#   Final Val Acc Fold 118: 100.00%
#
# Fold 119/198
#   Epoch 1: Train Loss: 0.6062 | Val Acc: 100.00%
#   Epoch 11: Train Loss: 0.0680 | Val Acc: 88.89%
#   Epoch 21: Train Loss: 0.0433 | Val Acc: 88.89%
#   Epoch 31: Train Loss: 0.0155 | Val Acc: 72.22%
#   Epoch 41: Train Loss: 0.0147 | Val Acc: 55.56%
#   Epoch 50: Train Loss: 0.0294 | Val Acc: 61.11%
#   Final Val Acc Fold 119: 61.11%
#
# Fold 120/198
#   Epoch 1: Train Loss: 0.5982 | Val Acc: 100.00%
#   Epoch 11: Train Loss: 0.0501 | Val Acc: 90.00%
#   Epoch 21: Train Loss: 0.0336 | Val Acc: 100.00%
#   Epoch 31: Train Loss: 0.0254 | Val Acc: 50.00%
#   Epoch 41: Train Loss: 0.0185 | Val Acc: 100.00%
#   Epoch 50: Train Loss: 0.0114 | Val Acc: 80.00%
#   Final Val Acc Fold 120: 80.00%
#
# Fold 121/198
#   Epoch 1: Train Loss: 0.5900 | Val Acc: 100.00%
#   Epoch 11: Train Loss: 0.0409 | Val Acc: 83.33%
#   Epoch 21: Train Loss: 0.0162 | Val Acc: 66.67%
#   Epoch 31: Train Loss: 0.0273 | Val Acc: 66.67%
#   Epoch 41: Train Loss: 0.0189 | Val Acc: 66.67%
#   Epoch 50: Train Loss: 0.0133 | Val Acc: 66.67%
#   Final Val Acc Fold 121: 66.67%
#
# Fold 122/198
#   Epoch 1: Train Loss: 0.6082 | Val Acc: 0.00%
#   Epoch 11: Train Loss: 0.0441 | Val Acc: 80.00%
#   Epoch 21: Train Loss: 0.0315 | Val Acc: 40.00%
#   Epoch 31: Train Loss: 0.0448 | Val Acc: 60.00%
#   Epoch 41: Train Loss: 0.0156 | Val Acc: 100.00%
#   Epoch 50: Train Loss: 0.
| Val Acc: 75.00%
#   Epoch 50: Train Loss: 0.0225 | Val Acc: 75.00%
#   Final Val Acc Fold 173: 75.00%
#
# Fold 174/198
#   Epoch 1: Train Loss: 0.5837 | Val Acc: 60.00%
#   Epoch 11: Train Loss: 0.0500 | Val Acc: 20.00%
#   Epoch 21: Train Loss: 0.0334 | Val Acc: 100.00%
#   Epoch 31: Train Loss: 0.0137 | Val Acc: 100.00%
#   Epoch 41: Train Loss: 0.0177 | Val Acc: 60.00%
#   Epoch 50: Train Loss: 0.0132 | Val Acc: 100.00%
#   Final Val Acc Fold 174: 100.00%
#
# Fold 175/198
#   Epoch 1: Train Loss: 0.6052 | Val Acc: 0.00%
#   Epoch 11: Train Loss: 0.0727 | Val Acc: 75.00%
#   Epoch 21: Train Loss: 0.0442 | Val Acc: 75.00%
#   Epoch 31: Train Loss: 0.0416 | Val Acc: 50.00%
#   Epoch 41: Train Loss: 0.0125 | Val Acc: 75.00%
#   Epoch 50: Train Loss: 0.0344 | Val Acc: 100.00%
#   Final Val Acc Fold 175: 100.00%
#
# Fold 176/198
#   Epoch 1: Train Loss: 0.6057 | Val Acc: 75.00%
#   Epoch 11: Train Loss: 0.0714 | Val Acc: 75.00%
#   Epoch 21: Train Loss: 0.0444 | Val Acc: 75.00%
#   Epoch 31: Train Loss: 0.0206 | Val Acc: 75.00%
#   Epoch 41: Train Loss: 0.0205 | Val Acc: 75.00%
#   Epoch 50: Train Loss: 0.0204 | Val Acc: 50.00%
#   Final Val Acc Fold 176: 50.00%
#
# Fold 177/198
#   Epoch 1: Train Loss: 0.5960 | Val Acc: 23.08%
#   Epoch 11: Train Loss: 0.0522 | Val Acc: 7.69%
#   Epoch 21: Train Loss: 0.0306 | Val Acc: 61.54%
#   Epoch 31: Train Loss: 0.0383 | Val Acc: 69.23%
#   Epoch 41: Train Loss: 0.0221 | Val Acc: 53.85%
#   Epoch 50: Train Loss: 0.0177 | Val Acc: 69.23%
#   Final Val Acc Fold 177: 69.23%
#
# Fold 178/198
#   Epoch 1: Train Loss: 0.5922 | Val Acc: 0.00%
#   Epoch 11: Train Loss: 0.0757 | Val Acc: 83.33%
#   Epoch 21: Train Loss: 0.0231 | Val Acc: 91.67%
#   Epoch 31: Train Loss: 0.0233 | Val Acc: 100.00%
#   Epoch 41: Train Loss: 0.0085 | Val Acc: 83.33%
#   Epoch 50: Train Loss: 0.0364 | Val Acc: 100.00%
#   Final Val Acc Fold 178: 100.00%
#
# Fold 179/198
#   Epoch 1: Train Loss: 0.6020 | Val Acc: 81.82%
#   Epoch 11: Train Loss: 0.0692 | Val Acc: 0.00%
#   Epoch 21: Train Loss: 0.0189 | Val Acc: 81.82%
#   Epoch 31: Train Loss: 0.0210 | Val Acc: 90.91%
#   Epoch 41: Train Loss: 0.0250 | Val Acc: 100.00%
#   Epoch 50: Train Loss: 0.0230 | Val Acc: 90.91%
#   Final Val Acc Fold 179: 90.91%
#
# Fold 180/198
#   Epoch 1: Train Loss: 0.6131 | Val Acc: 0.00%
#   Epoch 11: Train Loss: 0.0498 | Val Acc: 60.00%
#   Epoch 21: Train Loss: 0.0334 | Val Acc: 0.00%
#   Epoch 31: Train Loss: 0.0254 | Val Acc: 100.00%
#   Epoch 41: Train Loss: 0.0188 | Val Acc: 40.00%
#   Epoch 50: Train Loss: 0.0141 | Val Acc: 100.00%
#   Final Val Acc Fold 180: 100.00%
#
# Fold 181/198
#   Epoch 1: Train Loss: 0.5856 | Val Acc: 23.53%
#   Epoch 11: Train Loss: 0.0502 | Val Acc: 88.24%
#   Epoch 21: Train Loss: 0.0433 | Val Acc: 94.12%
#   Epoch 31: Train Loss: 0.0112 | Val Acc: 76.47%
#   Epoch 41: Train Loss: 0.0274 | Val Acc: 100.00%
#   Epoch 50: Train Loss: 0.
| Val Acc: 0.00%
#   Epoch 11: Train Loss: 0.0576 | Val Acc: 87.50%
#   Epoch 21: Train Loss: 0.0267 | Val Acc: 75.00%
#   Epoch 31: Train Loss: 0.0226 | Val Acc: 87.50%
#   Epoch 41: Train Loss: 0.0171 | Val Acc: 87.50%
#   Epoch 50: Train Loss: 0.0247 | Val Acc: 87.50%
#   Final Val Acc Fold 189: 87.50%
#
# Fold 190/198
#   Epoch 1: Train Loss: 0.5820 | Val Acc: 100.00%
#   Epoch 11: Train Loss: 0.0724 | Val Acc: 100.00%
#   Epoch 21: Train Loss: 0.0201 | Val Acc: 100.00%
#   Epoch 31: Train Loss: 0.0228 | Val Acc: 94.12%
#   Epoch 41: Train Loss: 0.0065 | Val Acc: 100.00%
#   Epoch 50: Train Loss: 0.0085 | Val Acc: 94.12%
#   Final Val Acc Fold 190: 94.12%
#
# Fold 191/198
#   Epoch 1: Train Loss: 0.5866 | Val Acc: 0.00%
#   Epoch 11: Train Loss: 0.0616 | Val Acc: 22.22%
#   Epoch 21: Train Loss: 0.0390 | Val Acc: 66.67%
#   Epoch 31: Train Loss: 0.0197 | Val Acc: 0.00%
#   Epoch 41: Train Loss: 0.0131 | Val Acc: 11.11%
#   Epoch 50: Train Loss: 0.0059 | Val Acc: 100.00%
#   Final Val Acc Fold 191: 100.00%
#
# Fold 192/198
#   Epoch 1: Train Loss: 0.6060 | Val Acc: 55.56%
#   Epoch 11: Train Loss: 0.0547 | Val Acc: 77.78%
#   Epoch 21: Train Loss: 0.0250 | Val Acc: 100.00%
#   Epoch 31: Train Loss: 0.0274 | Val Acc: 88.89%
#   Epoch 41: Train Loss: 0.0171 | Val Acc: 100.00%
#   Epoch 50: Train Loss: 0.0160 | Val Acc: 100.00%
#   Final Val Acc Fold 192: 100.00%
#
# Fold 193/198
#   Epoch 1: Train Loss: 0.5891 | Val Acc: 10.00%
#   Epoch 11: Train Loss: 0.0491 | Val Acc: 60.00%
#   Epoch 21: Train Loss: 0.0227 | Val Acc: 50.00%
#   Epoch 31: Train Loss: 0.0245 | Val Acc: 90.00%
#   Epoch 41: Train Loss: 0.0151 | Val Acc: 70.00%
#   Epoch 50: Train Loss: 0.0152 | Val Acc: 100.00%
#   Final Val Acc Fold 193: 100.00%
#
# Fold 194/198
#   Epoch 1: Train Loss: 0.6221 | Val Acc: 36.36%
#   Epoch 11: Train Loss: 0.0605 | Val Acc: 100.00%
#   Epoch 21: Train Loss: 0.0276 | Val Acc: 36.36%
#   Epoch 31: Train Loss: 0.0269 | Val Acc: 36.36%
#   Epoch 41: Train Loss: 0.0208 | Val Acc: 72.73%
#   Epoch 50: Train Loss: 0.0218 | Val Acc: 72.73%
#   Final Val Acc Fold 194: 72.73%
#
# Fold 195/198
#   Epoch 1: Train Loss: 0.6211 | Val Acc: 0.00%
#   Epoch 11: Train Loss: 0.0589 | Val Acc: 100.00%
#   Epoch 21: Train Loss: 0.0380 | Val Acc: 100.00%
#   Epoch 31: Train Loss: 0.0312 | Val Acc: 100.00%
#   Epoch 41: Train Loss: 0.0226 | Val Acc: 100.00%
#   Epoch 50: Train Loss: 0.0226 | Val Acc: 100.00%
#   Final Val Acc Fold 195: 100.00%
#
# Fold 196/198
#   Epoch 1: Train Loss: 0.5948 | Val Acc: 0.00%
#   Epoch 11: Train Loss: 0.0610 | Val Acc: 66.67%
#   Epoch 21: Train Loss: 0.0363 | Val Acc: 100.00%
#   Epoch 31: Train Loss: 0.0376 | Val Acc: 33.33%
#   Epoch 41: Train Loss: 0.0275 | Val Acc: 100.00%
#   Epoch 50: Train Loss: 0.0163 | Val Acc: 66.67%
#   Final Val Acc Fold 196: 66.67%
#
# Fold 197/198
#   Epoch 1: Train Loss: 0.6032 | Val Acc: 25.00%
#   Epoch 11: Train Loss: 0.0595 | Val Acc: 100.00%
#   Epoch 21: Train Loss: 0.0197 | Val Acc: 100.00%
#   Epoch 31: Train Loss: 0.0306 | Val Acc: 100.00%
#   Epoch 41: Train Loss: 0.0653 | Val Acc: 75.00%
#   Epoch 50: Train Loss: 0.0173 | Val Acc: 100.00%
#   Final Val Acc Fold 197: 100.00%
#
# Fold 198/198
#   Epoch 1: Train Loss: 0.5975 | Val Acc: 50.00%
#   Epoch 11: Train Loss: 0.0562 | Val Acc: 100.00%
#   Epoch 21: Train Loss: 0.0443 | Val Acc: 100.00%
#   Epoch 31: Train Loss: 0.0309 | Val Acc: 100.00%
#   Epoch 41: Train Loss: 0.0352 | Val Acc: 100.00%
#   Epoch 50: Train Loss: 0.0282 | Val Acc: 50.00%
#   Final Val Acc Fold 198: 50.00%
#
# --- Resultados Leave-One-Subject-Out (LOSO) ---
# Accuracy promedio a través de los pacientes: 70.80% +/- 30.50%

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Extraemos todas las pérdidas en matrices numpy
# history_per_fold contiene ~198 diccionarios. Convertimos las listas a arrays de forma (n_folds, n_epochs)
train_losses = np.array([h['train_loss'] for h in history_per_fold])
val_losses = np.array([h['val_loss'] for h in history_per_fold])

# 2. Calculamos la media y la desviación estándar a lo largo de los folds (axis=0)
mean_train = np.mean(train_losses, axis=0)
std_train = np.std(train_losses, axis=0)

mean_val = np.mean(val_losses, axis=0)
std_val = np.std(val_losses, axis=0)

# Eje X basado en la cantidad de épocas
epochs = range(1, len(mean_train) + 1)

# 3. Graficamos
plt.figure(figsize=(12, 6))

# Línea y sombra de Entrenamiento
plt.plot(epochs, mean_train, color='blue', label='Train Loss (Media)')
plt.fill_between(epochs, mean_train - std_train, mean_train + std_train, color='blue', alpha=0.2)

# Línea y sombra de Validación
plt.plot(epochs, mean_val, color='orange', label='Val Loss (Media)')
plt.fill_between(epochs, mean_val - std_val, mean_val + std_val, color='orange', alpha=0.2)

plt.title('Training & Validation Loss Promedio (LOSO)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# --- EVALUACIÓN FINAL EN TEST SET ---
# Entrenamos un modelo final con todo el set de Train/Validation o usamos el mejor del CV
# Para este reporte, re-entrenaremos en todo X_train_val para evaluar en X_test

print("\n--- Entrenando Modelo Final en todo Train+Val para evaluar en Test ---")

full_train_ds = TensorDataset(X_train_val, y_train_val)
full_train_loader = DataLoader(full_train_ds, batch_size=BATCH_SIZE, shuffle=True)
test_ds = TensorDataset(X_test, y_test)
test_loader = DataLoader(test_ds, batch_size=BATCH_SIZE, shuffle=False)

final_model = RedNeuronalGeneral(input_shape=X_all.shape[1:], num_classes=3).to(device)
optimizer = optim.Adam(final_model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

for epoch in range(EPOCHS):
    final_model.train()
    for inputs, labels in full_train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = final_model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

# Evaluación
final_model.eval()
all_preds = []
all_labels = []

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = final_model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        
        all_preds.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

# --- MATRIZ DE CONFUSIÓN Y REPORTE ---
cm = confusion_matrix(all_labels, all_preds)
class_names = list(class_map.keys()) if 'class_map' in locals() else ['Adenoma', 'Glioma', 'Meningioma'] # Fallback names if map missing context

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix - Test Set')
plt.show()

print("\n--- Classification Report (Test Set) ---")
print(classification_report(all_labels, all_preds, target_names=class_names))
# Out:
# --- Entrenando Modelo Final en todo Train+Val para evaluar en Test ---
# --- Classification Report (Test Set) ---
#               precision    recall  f1-score   support
#
#      Adenoma       0.82      0.95      0.88       110
#       Glioma       0.70      0.40      0.51       107
#   Meningioma       0.56      0.71      0.63       111
#
#     accuracy                           0.69       328
#    macro avg       0.70      0.69      0.67       328
# weighted avg       0.70      0.69      0.67       328
