# %% [markdown]
# # Análisis del Dataset_Balanceado_700
#
# Este script cuenta cuántas imágenes hay por cada clase en el dataset `Dataset_Balanceado_700` y verifica sus dimensiones.
# Dado que los archivos son `.npz`, se itera sobre todos los archivos, se cargan y se suman las imágenes contenidas en cada uno.

# %%
import os
import numpy as np

# Ruta del dataset
dataset_path = 'Dataset_Balanceado_700'

if not os.path.exists(dataset_path):
    # Ajuste de ruta si se corre desde Propuesta1/
    if os.path.exists('../Dataset_Balanceado_700'):
        dataset_path = '../Dataset_Balanceado_700'
    else:
        print(f"Error: La carpeta '{dataset_path}' no se encuentra en el directorio actual.")

if os.path.exists(dataset_path):
    # Obtener las carpetas de las clases
    classes = [d for d in os.listdir(dataset_path) if os.path.isdir(os.path.join(dataset_path, d))]
    
    print(f"{'Clase':<25} | {'Archivos':<10} | {'Total Imágenes':<15} | {'Dimensiones (WxH)':<20}")
    print("-" * 80)
    
    total_dataset_images = 0
    
    for class_name in classes:
        class_dir = os.path.join(dataset_path, class_name)
        files = [f for f in os.listdir(class_dir) if f.lower().endswith('.npz')]
        
        num_files = len(files)
        total_class_images = 0
        dims_set = set()
        
        for file_name in files:
            file_path = os.path.join(class_dir, file_name)
            try:
                with np.load(file_path) as data:
                    # Basado en la salida anterior, la clave es 'imagenes'
                    if 'imagenes' in data:
                        imgs = data['imagenes']
                        # Asumimos formato (N, H, W) donde N es el numero de imagenes
                        n_imgs = imgs.shape[0]
                        total_class_images += n_imgs
                        
                        if len(imgs.shape) >= 3:
                             dims_set.add(f"{imgs.shape[2]}x{imgs.shape[1]}") # WxH
                    else:
                        # Si no encuentra 'imagenes', intentar listar claves disponibles
                        print(f"Advertencia: 'imagenes' no encontrado en {file_name}. Claves: {list(data.files)}")

            except Exception as e:
                print(f"Error leyendo {file_name}: {e}")

        total_dataset_images += total_class_images
        
        dims_summary = ", ".join(list(dims_set)) if dims_set else "N/A"
        
        print(f"{class_name:<25} | {num_files:<10} | {total_class_images:<15} | {dims_summary:<20}")

    print("-" * 80)
    print(f"Total de imágenes en el dataset: {total_dataset_images}")
# Out:
# Clase                     | Archivos   | Total Imágenes  | Dimensiones (WxH)
# --------------------------------------------------------------------------------
# Adenoma_hipofisario       | 62         | 699             | 128x128
# Glioma                    | 89         | 699             | 128x128
# Meningioma                | 82         | 700             | 128x128
# --------------------------------------------------------------------------------
# Total de imágenes en el dataset: 2098

# %% [markdown]
# # Implementación de CNN Cuántica con Validación Cruzada Estratificada (5-Fold)
#
# En esta sección se implementa el flujo de trabajo completo:
# 1. **Preprocesamiento Cuántico**: Se aplica convolución cuántica a las imágenes.
# 2. **División de Datos**: Se respeta la estructura de pacientes (archivos .npz) para evitar data leakage. Se separa un 15% para Test y el resto para 5-Fold CV.
# 3. **Entrenamiento**: Se entrena una Red Neuronal (MLP) sobre las características cuánticas.
# 4. **Evaluación**: Se reportan métricas de rendimiento.

# %%
import sys
# Aseguramos que se pueda importar quantum_utils si está en el mismo directorio
sys.path.append('.')

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import LeaveOneGroupOut, train_test_split
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm
import quantum_utils as qu

# Configuración de dispositivo
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Usando dispositivo de entrenamiento (Red Neuronal): {device}")
# Out:
# Usando dispositivo de entrenamiento (Red Neuronal): cuda

# %%
class RedNeuronalGeneral(nn.Module):
    def __init__(self, input_shape, num_classes=3):
        super(RedNeuronalGeneral, self).__init__()
        
        # 1. Calculamos dinámicamente el tamaño aplanado (Flatten)
        self.input_dim = np.prod(input_shape)
        
        # print(f"Inicializando red para entrada {input_shape} -> {self.input_dim} neuronas de entrada.")

        # 2. Definimos la arquitectura Flatten + MLP
        #       Flatten -> Dense -> Dense -> Out
        
        self.flatten = nn.Flatten()
        
        self.layers = nn.Sequential(
            # Bloque Denso 1 
            nn.Linear(self.input_dim, 256), # De n entradas a 256 neuronas
            nn.BatchNorm1d(256), # Batch Normalization
            nn.LeakyReLU(0.1), # Activación LeakyReLU alpha=0.1
            nn.Dropout(0.3), # Dropout 30%
            
            # Bloque Denso 2
            nn.Linear(256, 128), # De 256 a 128 neuronas
            nn.BatchNorm1d(128), # Batch Normalization
            nn.LeakyReLU(0.1), # Activación LeakyReLU alpha=0.1
            nn.Dropout(0.2), # Dropout 20%
            
            # Capa de Salida (3 clases: Meningioma, Glioma, T. Pituitario)
            nn.Linear(128, num_classes)
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.layers(x)
        return logits

# %%
def cargar_y_procesar_dataset(dataset_path, num_qubits=4, embedding='amplitude', feature_maps=1, max_images_per_class=None):
    """
    Carga los archivos .npz, aplica convolución cuántica y estructura los datos para CV.
    Devuelve:
        - data_features: Lista de tensores procesados (imágenes)
        - data_labels: Lista de etiquetas
        - data_groups: Lista de IDs de pacientes (para garantizar CV estratificado por grupo)
    """
    
    features_list = []
    labels_list = []
    groups_list = []
    
    # Mapeo de clases a enteros
    class_map = {}
    classes = sorted([d for d in os.listdir(dataset_path) if os.path.isdir(os.path.join(dataset_path, d))])
    for idx, c in enumerate(classes):
        class_map[c] = idx
    
    print(f"Mapeo de Clases: {class_map}")
    
    for class_name in classes:
        class_dir = os.path.join(dataset_path, class_name)
        files = [f for f in os.listdir(class_dir) if f.lower().endswith('.npz')]
        
        if max_images_per_class:
            # Para pruebas rápidas
            files = files[:max_images_per_class]
        
        print(f"Procesando clase {class_name} ({len(files)} pacientes)...")
        
        for file_name in tqdm(files, desc=f"Clase {class_name}"):
            file_path = os.path.join(class_dir, file_name)
            patient_id = file_name.replace('.npz', '')
            
            try:
                with np.load(file_path) as data:
                    if 'imagenes' in data:
                        imgs = data['imagenes'] # Shape (N, H, W)
                        
                        for i in range(imgs.shape[0]):
                            img = imgs[i]
                            
                            # --- CONVOLUCIÓN CUÁNTICA ---
                            # quantum_conv devuelve (H_out, W_out, channels)
                            q_feat = qu.quantum_conv(img, num_qubits, embedding, feature_maps)
                            
                            # Transponer a formato PyTorch (C, H, W)
                            # q_feat shape original: (H, W, C) -> PyTorch: (C, H, W)
                            q_feat_tensor = torch.tensor(q_feat, dtype=torch.float32).permute(2, 0, 1)
                            
                            features_list.append(q_feat_tensor)
                            labels_list.append(class_map[class_name])
                            groups_list.append(patient_id)
                            
            except Exception as e:
                print(f"Error al procesar {file_name}: {e}")
                raise e
                
    return features_list, labels_list, groups_list

# Parametros Cuánticos
NUM_QUBITS = 4
EMBEDDING = 'amplitude'
FEATURE_MAPS = 1

# ADVERTENCIA: Esto puede tardar mucho si se corre en el dataset completo.
# Para probar el flujo primero, puedes descomentar 'max_images_per_class=2'
print("Iniciando extracción de características cuánticas...")
X_raw, y_raw, group_raw = cargar_y_procesar_dataset(dataset_path, 
                                                num_qubits=NUM_QUBITS, 
                                                embedding=EMBEDDING, 
                                                feature_maps=FEATURE_MAPS,
                                                # max_images_per_class=2 # Descomentar para debug rapido
                                                )

# Convertir a tensores apilados
X_all = torch.stack(X_raw)
y_all = torch.tensor(y_raw, dtype=torch.long)
groups_all = np.array(group_raw)

print(f"\nProcesamiento Completado.")
print(f"X shape: {X_all.shape}")
print(f"y shape: {y_all.shape}")
print(f"Grupos (Pacientes): {len(np.unique(groups_all))} únicos.")
# Out:
# Iniciando extracción de características cuánticas...
# Mapeo de Clases: {'Adenoma_hipofisario': 0, 'Glioma': 1, 'Meningioma': 2}
# Procesando clase Adenoma_hipofisario (62 pacientes)...
# Clase Adenoma_hipofisario:   0%|          | 0/62 [00:00<?, ?it/s]
# Procesando clase Glioma (89 pacientes)...
# Clase Glioma:   0%|          | 0/89 [00:00<?, ?it/s]
# Procesando clase Meningioma (82 pacientes)...
# Clase Meningioma:   0%|          | 0/82 [00:00<?, ?it/s]
# Procesamiento Completado.
# X shape: torch.Size([2098, 1, 32, 32])
# y shape: torch.Size([2098])
# Grupos (Pacientes): 233 únicos.

# %%
# --- ESTRATEGIA DE DIVISIÓN DE DATOS ---
# 1. Separar Test Set (15% de PACIENTES) preservando estratificación
#    Primero identificamos etiquetas por paciente para estratificar
unique_patients, patient_indices = np.unique(groups_all, return_index=True)
patient_labels = y_all[patient_indices].numpy()

train_val_patients, test_patients = train_test_split(unique_patients, 
                                                    test_size=0.15, 
                                                    stratify=patient_labels,
                                                    random_state=42)

print(f"Total Pacientes: {len(unique_patients)}")
print(f"Pacientes Train/Val: {len(train_val_patients)}")
print(f"Pacientes Test: {len(test_patients)}")

# Crear máscaras booleanas para filtrar X_all y y_all
# np.isin verifica si cada elemento de groups_all está en la lista de pacientes
mask_train_val = np.isin(groups_all, train_val_patients)
mask_test = np.isin(groups_all, test_patients)

X_train_val = X_all[mask_train_val]
y_train_val = y_all[mask_train_val]
groups_train_val = groups_all[mask_train_val]

X_test = X_all[mask_test]
y_test = y_all[mask_test]

print(f"Imágenes Train/Val: {len(X_train_val)}")
print(f"Imágenes Test: {len(X_test)}")
# Out:
# Total Pacientes: 233
# Pacientes Train/Val: 198
# Pacientes Test: 35
# Imágenes Train/Val: 1770
# Imágenes Test: 328

# %%
# --- LOSO CROSS VALIDATION STRATIFIED ---
BATCH_SIZE = 32
EPOCHS = 50
N_SPLITS = len(unique_patients)

loso = LeaveOneGroupOut()

fold_metrics = []
history_per_fold = []

print(f"Iniciando LOSO Cross Validation con {N_SPLITS} sujetos/folds...")

for fold, (train_idx, val_idx) in enumerate(loso.split(X_train_val, y_train_val, groups_train_val)):
    print(f"\nFold {fold+1}/{N_SPLITS}")
    
    # Crear datasets para el fold actual
    # Convertir a Tensores si no lo son
    X_f_train, y_f_train = X_train_val[train_idx], y_train_val[train_idx]
    X_f_val, y_f_val = X_train_val[val_idx], y_train_val[val_idx]
    
    train_ds = TensorDataset(X_f_train, y_f_train)
    val_ds = TensorDataset(X_f_val, y_f_val)
    
    train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, drop_last=True)
    val_loader = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False)
    
    # Inicializar Modelo
    # Input shape: (C, H, W)
    input_shape = X_all.shape[1:]
    model = RedNeuronalGeneral(input_shape=input_shape, num_classes=3).to(device)
    
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.CrossEntropyLoss()
    
    # Historial para graficar
    fold_history = {'train_loss': [], 'val_loss': [], 'val_acc': []}
    
    for epoch in range(EPOCHS):
        # Train
        model.train()
        running_loss = 0.0
        correct_train = 0
        total_train = 0
        
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item()
            
        avg_train_loss = running_loss / len(train_loader)
        
        # Validation
        model.eval()
        val_loss = 0.0
        correct_val = 0
        total_val = 0
        
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                
                _, predicted = torch.max(outputs.data, 1)
                total_val += labels.size(0)
                correct_val += (predicted == labels).sum().item()
        
        avg_val_loss = val_loss / len(val_loader)
        val_accuracy = 100 * correct_val / total_val
        
        fold_history['train_loss'].append(avg_train_loss)
        fold_history['val_loss'].append(avg_val_loss)
        fold_history['val_acc'].append(val_accuracy)
        
        # if((epoch + 1) % 10 == 0):
        #     print(f"  Epoch {epoch+1}: Train Loss: {avg_train_loss:.4f} | Val Acc: {val_accuracy:.2f}%")
    
    print(f"  Final Val Acc Fold {fold+1}: {fold_history['val_acc'][-1]:.2f}%")
    history_per_fold.append(fold_history)
    fold_metrics.append(fold_history['val_acc'][-1])

print("\n--- Resultados Cross-Validation ---")
print(f"Accuracy promedio: {np.mean(fold_metrics):.2f}% +/- {np.std(fold_metrics):.2f}%")
# Out:
# Iniciando LOSO Cross Validation con 233 sujetos/folds...
#
# Fold 1/233
#   Final Val Acc Fold 1: 88.24%
#
# Fold 2/233
#   Final Val Acc Fold 2: 0.00%
#
# Fold 3/233
#   Final Val Acc Fold 3: 100.00%
#
# Fold 4/233
#   Final Val Acc Fold 4: 100.00%
#
# Fold 5/233
#   Final Val Acc Fold 5: 66.67%
#
# Fold 6/233
#   Final Val Acc Fold 6: 64.71%
#
# Fold 7/233
#   Final Val Acc Fold 7: 100.00%
#
# Fold 8/233
#   Final Val Acc Fold 8: 0.00%
#
# Fold 9/233
#   Final Val Acc Fold 9: 100.00%
#
# Fold 10/233
#   Final Val Acc Fold 10: 100.00%
#
# Fold 11/233
#   Final Val Acc Fold 11: 75.00%
#
# Fold 12/233
#   Final Val Acc Fold 12: 88.89%
#
# Fold 13/233
#   Final Val Acc Fold 13: 75.00%
#
# Fold 14/233
#   Final Val Acc Fold 14: 100.00%
#
# Fold 15/233
#   Final Val Acc Fold 15: 66.67%
#
# Fold 16/233
#   Final Val Acc Fold 16: 100.00%
#
# Fold 17/233
#   Final Val Acc Fold 17: 25.00%
#
# Fold 18/233
#   Final Val Acc Fold 18: 100.00%
#
# Fold 19/233
#   Final Val Acc Fold 19: 75.00%
#
# Fold 20/233
#   Final Val Acc Fold 20: 92.31%
#
# Fold 21/233
#   Final Val Acc Fold 21: 100.00%
#
# Fold 22/233
#   Final Val Acc Fold 22: 100.00%
#
# Fold 23/233
#   Final Val Acc Fold 23: 100.00%
#
# Fold 24/233
#   Final Val Acc Fold 24: 100.00%
#
# Fold 25/233
#   Final Val Acc Fold 25: 60.00%
#
# Fold 26/233
#   Final Val Acc Fold 26: 66.67%
#
# Fold 27/233
#   Final Val Acc Fold 27: 100.00%
#
# Fold 28/233
#   Final Val Acc Fold 28: 100.00%
#
# Fold 29/233
#   Final Val Acc Fold 29: 64.29%
#
# Fold 30/233
#   Final Val Acc Fold 30: 100.00%
#
# Fold 31/233
#   Final Val Acc Fold 31: 100.00%
#
# Fold 32/233
#   Final Val Acc Fold 32: 23.53%
#
# Fold 33/233
#   Final Val Acc Fold 33: 100.00%
#
# Fold 34/233
#   Final Val Acc Fold 34: 60.00%
#
# Fold 35/233
#   Final Val Acc Fold 35: 100.00%
#
# Fold 36/233
#   Final Val Acc Fold 36: 100.00%
#
# Fold 37/233
#   Final Val Acc Fold 37: 88.24%
#
# Fold 38/233
#   Final Val Acc Fold 38: 100.00%
#
# Fold 39/233
#   Final Val Acc Fold 39: 88.89%
#
# Fold 40/233
#   Final Val Acc Fold 40: 83.33%
#
# Fold 41/233
#   Final Val Acc Fold 41: 80.00%
#
# Fold 42/233
#   Final Val Acc Fold 42: 20.00%
#
# Fold 43/233
#   Final Val Acc Fold 43: 83.33%
#
# Fold 44/233
#   Final Val Acc Fold 44: 88.89%
#
# Fold 45/233
#   Final Val Acc Fold 45: 0.00%
#
# Fold 46/233
#   Final Val Acc Fold 46: 100.00%
#
# Fold 47/233
#   Final Val Acc Fold 47: 77.78%
#
# Fold 48/233
#   Final Val Acc Fold 48: 100.00%
#
# Fold 49/233
#   Final Val Acc Fold 49: 46.15%
#
# Fold 50/233
#   Final Val Acc Fold 50: 12.50%
#
# Fold 51/233
#   Final Val Acc Fold 51: 100.00%
#
# Fold 52/233
#   Final Val Acc Fold 52: 100.00%
#
# Fold 53/233
#   Final Val Acc Fold 53: 93.33%
#
# Fold 54/233
#   Final Val Acc Fold 54: 100.00%
#
# Fold 55/233
#   Final Val Acc Fold 55: 33.33%
#
# Fold 56/233
#   Final Val Acc Fold 56: 100.00%
#
# Fold 57/233
#   Final Val Acc Fold 57: 78.57%
#
# Fold 58/233
#   Final Val Acc Fold 58: 100.00%
#
# Fold 59/233
#   Final Val Acc Fold 59: 37.50%
#
# Fold 60/233
#   Final Val Acc Fold 60: 100.00%
#
# Fold 61/233
#   Final Val Acc Fold 61: 0.00%
#
# Fold 62/233
#   Final Val Acc Fold 62: 88.89%
#
# Fold 63/233
#   Final Val Acc Fold 63: 66.67%
#
# Fold 64/233
#   Final Val Acc Fold 64: 60.00%
#
# Fold 65/233
#   Final Val Acc Fold 65: 100.00%
#
# Fold 66/233
#   Final Val Acc Fold 66: 72.73%
#
# Fold 67/233
#   Final Val Acc Fold 67: 58.33%
#
# Fold 68/233
#   Final Val Acc Fold 68: 100.00%
#
# Fold 69/233
#   Final Val Acc Fold 69: 90.91%
#
# Fold 70/233
#   Final Val Acc Fold 70: 100.00%
#
# Fold 71/233
#   Final Val Acc Fold 71: 75.00%
#
# Fold 72/233
#   Final Val Acc Fold 72: 0.00%
#
# Fold 73/233
#   Final Val Acc Fold 73: 66.67%
#
# Fold 74/233
#   Final Val Acc Fold 74: 100.00%
#
# Fold 75/233
#   Final Val Acc Fold 75: 100.00%
#
# Fold 76/233
#   Final Val Acc Fold 76: 88.89%
#
# Fold 77/233
#   Final Val Acc Fold 77: 84.62%
#
# Fold 78/233
#   Final Val Acc Fold 78: 80.00%
#
# Fold 79/233
#   Final Val Acc Fold 79: 83.33%
#
# Fold 80/233
#   Final Val Acc Fold 80: 100.00%
#
# Fold 81/233
#   Final Val Acc Fold 81: 100.00%
#
# Fold 82/233
#   Final Val Acc Fold 82: 100.00%
#
# Fold 83/233
#   Final Val Acc Fold 83: 70.00%
#
# Fold 84/233
#   Final Val Acc Fold 84: 66.67%
#
# Fold 85/233
#   Final Val Acc Fold 85: 0.00%
#
# Fold 86/233
#   Final Val Acc Fold 86: 90.00%
#
# Fold 87/233
#   Final Val Acc Fold 87: 0.00%
#
# Fold 88/233
#   Final Val Acc Fold 88: 8.33%
#
# Fold 89/233
#   Final Val Acc Fold 89: 83.33%
#
# Fold 90/233
#   Final Val Acc Fold 90: 85.71%
#
# Fold 91/233
#   Final Val Acc Fold 91: 70.00%
#
# Fold 92/233
#   Final Val Acc Fold 92: 100.00%
#
# Fold 93/233
#   Final Val Acc Fold 93: 100.00%
#
# Fold 94/233
#   Final Val Acc Fold 94: 100.00%
#
# Fold 95/233
#   Final Val Acc Fold 95: 66.67%
#
# Fold 96/233
#   Final Val Acc Fold 96: 37.50%
#
# Fold 97/233
#   Final Val Acc Fold 97: 80.00%
#
# Fold 98/233
#   Final Val Acc Fold 98: 50.00%
#
# Fold 99/233
#   Final Val Acc Fold 99: 100.00%
#
# Fold 100/233
#   Final Val Acc Fold 100: 100.00%
#
# Fold 101/233
#   Final Val Acc Fold 101: 100.00%
#
# Fold 102/233
#   Final Val Acc Fold 102: 46.67%
#
# Fold 103/233
#   Final Val Acc Fold 103: 100.00%
#
# Fold 104/233
#   Final Val Acc Fold 104: 100.00%
#
# Fold 105/233
#   Final Val Acc Fold 105: 89.47%
#
# Fold 106/233
#   Final Val Acc Fold 106: 87.50%
#
# Fold 107/233
#   Final Val Acc Fold 107: 100.00%
#
# Fold 108/233
#   Final Val Acc Fold 108: 100.00%
#
# Fold 109/233
#   Final Val Acc Fold 109: 100.00%
#
# Fold 110/233
#   Final Val Acc Fold 110: 50.00%
#
# Fold 111/233
#   Final Val Acc Fold 111: 33.33%
#
# Fold 112/233
#   Final Val Acc Fold 112: 50.00%
#
# Fold 113/233
#   Final Val Acc Fold 113: 0.00%
#
# Fold 114/233
#   Final Val Acc Fold 114: 25.00%
#
# Fold 115/233
#   Final Val Acc Fold 115: 40.00%
#
# Fold 116/233
#   Final Val Acc Fold 116: 0.00%
#
# Fold 117/233
#   Final Val Acc Fold 117: 0.00%
#
# Fold 118/233
#   Final Val Acc Fold 118: 60.00%
#
# Fold 119/233
#   Final Val Acc Fold 119: 77.78%
#
# Fold 120/233
#   Final Val Acc Fold 120: 80.00%
#
# Fold 121/233
#   Final Val Acc Fold 121: 33.33%
#
# Fold 122/233
#   Final Val Acc Fold 122: 0.00%
#
# Fold 123/233
#   Final Val Acc Fold 123: 66.67%
#
# Fold 124/233
#   Final Val Acc Fold 124: 0.00%
#
# Fold 125/233
#   Final Val Acc Fold 125: 100.00%
#
# Fold 126/233
#   Final Val Acc Fold 126: 100.00%
#
# Fold 127/233
#   Final Val Acc Fold 127: 100.00%
#
# Fold 128/233
#   Final Val Acc Fold 128: 88.89%
#
# Fold 129/233
#   Final Val Acc Fold 129: 100.00%
#
# Fold 130/233
#   Final Val Acc Fold 130: 44.44%
#
# Fold 131/233
#   Final Val Acc Fold 131: 66.67%
#
# Fold 132/233
#   Final Val Acc Fold 132: 100.00%
#
# Fold 133/233
#   Final Val Acc Fold 133: 66.67%
#
# Fold 134/233
#   Final Val Acc Fold 134: 73.68%
#
# Fold 135/233
#   Final Val Acc Fold 135: 91.67%
#
# Fold 136/233
#   Final Val Acc Fold 136: 100.00%
#
# Fold 137/233
#   Final Val Acc Fold 137: 92.31%
#
# Fold 138/233
#   Final Val Acc Fold 138: 100.00%
#
# Fold 139/233
#   Final Val Acc Fold 139: 100.00%
#
# Fold 140/233
#   Final Val Acc Fold 140: 86.67%
#
# Fold 141/233
#   Final Val Acc Fold 141: 33.33%
#
# Fold 142/233
#   Final Val Acc Fold 142: 100.00%
#
# Fold 143/233
#   Final Val Acc Fold 143: 100.00%
#
# Fold 144/233
#   Final Val Acc Fold 144: 100.00%
#
# Fold 145/233
#   Final Val Acc Fold 145: 100.00%
#
# Fold 146/233
#   Final Val Acc Fold 146: 100.00%
#
# Fold 147/233
#   Final Val Acc Fold 147: 100.00%
#
# Fold 148/233
#   Final Val Acc Fold 148: 100.00%
#
# Fold 149/233
#   Final Val Acc Fold 149: 100.00%
#
# Fold 150/233
#   Final Val Acc Fold 150: 100.00%
#
# Fold 151/233
#   Final Val Acc Fold 151: 100.00%
#
# Fold 152/233
#   Final Val Acc Fold 152: 100.00%
#
# Fold 153/233
#   Final Val Acc Fold 153: 94.74%
#
# Fold 154/233
#   Final Val Acc Fold 154: 75.00%
#
# Fold 155/233
#   Final Val Acc Fold 155: 81.82%
#
# Fold 156/233
#   Final Val Acc Fold 156: 100.00%
#
# Fold 157/233
#   Final Val Acc Fold 157: 80.00%
#
# Fold 158/233
#   Final Val Acc Fold 158: 100.00%
#
# Fold 159/233
#   Final Val Acc Fold 159: 100.00%
#
# Fold 160/233
#   Final Val Acc Fold 160: 100.00%
#
# Fold 161/233
#   Final Val Acc Fold 161: 100.00%
#
# Fold 162/233
#   Final Val Acc Fold 162: 100.00%
#
# Fold 163/233
#   Final Val Acc Fold 163: 100.00%
#
# Fold 164/233
#   Final Val Acc Fold 164: 85.71%
#
# Fold 165/233
#   Final Val Acc Fold 165: 100.00%
#
# Fold 166/233
#   Final Val Acc Fold 166: 100.00%
#
# Fold 167/233
#   Final Val Acc Fold 167: 87.50%
#
# Fold 168/233
#   Final Val Acc Fold 168: 100.00%
#
# Fold 169/233
#   Final Val Acc Fold 169: 100.00%
#
# Fold 170/233
#   Final Val Acc Fold 170: 58.33%
#
# Fold 171/233
#   Final Val Acc Fold 171: 100.00%
#
# Fold 172/233
#   Final Val Acc Fold 172: 100.00%
#
# Fold 173/233
#   Final Val Acc Fold 173: 100.00%
#
# Fold 174/233
#   Final Val Acc Fold 174: 100.00%
#
# Fold 175/233
#   Final Val Acc Fold 175: 100.00%
#
# Fold 176/233
#   Final Val Acc Fold 176: 75.00%
#
# Fold 177/233
#   Final Val Acc Fold 177: 100.00%
#
# Fold 178/233
#   Final Val Acc Fold 178: 83.33%
#
# Fold 179/233
#   Final Val Acc Fold 179: 100.00%
#
# Fold 180/233
#   Final Val Acc Fold 180: 100.00%
#
# Fold 181/233
#   Final Val Acc Fold 181: 100.00%
#
# Fold 182/233
#   Final Val Acc Fold 182: 90.91%
#
# Fold 183/233
#   Final Val Acc Fold 183: 100.00%
#
# Fold 184/233
#   Final Val Acc Fold 184: 72.73%
#
# Fold 185/233
#   Final Val Acc Fold 185: 100.00%
#
# Fold 186/233
#   Final Val Acc Fold 186: 50.00%
#
# Fold 187/233
#   Final Val Acc Fold 187: 81.82%
#
# Fold 188/233
#   Final Val Acc Fold 188: 94.44%
#
# Fold 189/233
#   Final Val Acc Fold 189: 87.50%
#
# Fold 190/233
#   Final Val Acc Fold 190: 100.00%
#
# Fold 191/233
#   Final Val Acc Fold 191: 66.67%
#
# Fold 192/233
#   Final Val Acc Fold 192: 100.00%
#
# Fold 193/233
#   Final Val Acc Fold 193: 90.00%
#
# Fold 194/233
#   Final Val Acc Fold 194: 100.00%
#
# Fold 195/233
#   Final Val Acc Fold 195: 100.00%
#
# Fold 196/233
#   Final Val Acc Fold 196: 100.00%
#
# Fold 197/233
#   Final Val Acc Fold 197: 100.00%
#
# Fold 198/233
#   Final Val Acc Fold 198: 100.00%
#
# --- Resultados Cross-Validation ---
# Accuracy promedio: 79.63% +/- 28.99%

# %%
# --- VISUALIZACIÓN DE PÉRDIDAS (LOSS) ---
plt.figure(figsize=(12, 6))

for i, history in enumerate(history_per_fold):
    plt.plot(history['train_loss'], linestyle='--', label=f'Fold {i+1} Train')
    # plt.plot(history['val_loss'], label=f'Fold {i+1} Val')

plt.title('Training & Validation Loss per Fold')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# --- EVALUACIÓN FINAL EN TEST SET ---
# Entrenamos un modelo final con todo el set de Train/Validation o usamos el mejor del CV
# Para este reporte, re-entrenaremos en todo X_train_val para evaluar en X_test

print("\n--- Entrenando Modelo Final en todo Train+Val para evaluar en Test ---")

full_train_ds = TensorDataset(X_train_val, y_train_val)
full_train_loader = DataLoader(full_train_ds, batch_size=BATCH_SIZE, shuffle=True)
test_ds = TensorDataset(X_test, y_test)
test_loader = DataLoader(test_ds, batch_size=BATCH_SIZE, shuffle=False)

final_model = RedNeuronalGeneral(input_shape=X_all.shape[1:], num_classes=3).to(device)
optimizer = optim.Adam(final_model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

for epoch in range(EPOCHS):
    final_model.train()
    for inputs, labels in full_train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = final_model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

# Evaluación
final_model.eval()
all_preds = []
all_labels = []

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = final_model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        
        all_preds.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

# --- MATRIZ DE CONFUSIÓN Y REPORTE ---
cm = confusion_matrix(all_labels, all_preds)
class_names = list(class_map.keys()) if 'class_map' in locals() else ['Adenoma', 'Glioma', 'Meningioma'] # Fallback names if map missing context

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix - Test Set')
plt.show()

print("\n--- Classification Report (Test Set) ---")
print(classification_report(all_labels, all_preds, target_names=class_names))
# Out:
# --- Entrenando Modelo Final en todo Train+Val para evaluar en Test ---
# --- Classification Report (Test Set) ---
#               precision    recall  f1-score   support
#
#      Adenoma       0.90      0.94      0.92       110
#       Glioma       0.81      0.82      0.81       107
#   Meningioma       0.80      0.75      0.77       111
#
#     accuracy                           0.84       328
#    macro avg       0.83      0.84      0.83       328
# weighted avg       0.83      0.84      0.83       328
